# %% [markdown]
# # Fase 2: Limpieza y consolidacion
#
# Carga, calidad, duplicados, normalizacion temporal y exportacion de CSV limpios.

# %%
import sys
from pathlib import Path
sys.path.append(str((Path('..') / 'scripts').resolve()))
import generate_spotify_final as pipeline
pipeline.main()

# %% [markdown]
# Transformaciones: UTC a America/Mexico_City, variables temporales, normalizacion de dispositivo, clasificacion de contenido, sesiones con gaps mayores a 30 minutos, remocion de duplicados y exportacion sin IP.
