# %% [markdown]
# # Fase 4: Machine Learning
#
# Dos modelos por persona: K-Means mensual y regresion logistica para skip.

# %%
import json
summary = json.load(open('../reports/summary_combined.json', encoding='utf-8'))
for person in summary['people']:
    print('\n', person['metadata']['name'])
    print('K-Means:', person['ml']['clustering'])
    print('Skip classifier:', person['ml']['skip_classifier'])

# %% [markdown]
# Interpretacion: K-Means agrupa meses por intensidad, diversidad, skip, nocturnidad, concentracion y descubrimiento. La regresion logistica muestra que saltar canciones tiene senales observables, pero no es completamente determinista.
